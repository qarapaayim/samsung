# %% [markdown]
# ### Plotting in Python using matplotlib.pyplot

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# For compatibility across multiple platforms
import os
IB = os.environ.get('INSTABASE_URI',None) is not None
open = ib.open if IB else open

# %%
# Read Cities.csv and Countries.csv into lists of dictionaries
cities = []
with open('Cities.csv','rU') as f:
    rows = csv.DictReader(f)
    for r in rows:
        cities.append(r)
countries = []
with open('Countries.csv','rU') as f:
    rows = csv.DictReader(f)
    for r in rows:
        countries.append(r)
# Out:
# /home/aidar/Tools/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: 'U' mode is deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/aidar/Tools/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: 'U' mode is deprecated

# %%
# Introduction to scatterplots
x = [1, 2, 4, 6, 9]
y = [4, 5, 2, 7, 5]
plt.scatter(x, y)

# %%
# Scatterplot of temperature (y) versus latitude (x)
x = []
y = []
for city in cities:
    x.append(float(city['latitude']))
    y.append(float(city['temperature']))
plt.scatter(x, y)
# Add labels to axes
plt.xlabel('latitude')
plt.ylabel('temperature')
# Out:
# Text(0, 0.5, 'temperature')

# %%
# Scatterplot of latitude (y) versus longitude (x) colored by temperature
x = []
y = []
colors = []
for city in cities:
    x.append(float(city['longitude']))
    y.append(float(city['latitude']))
    if float(city['temperature']) < 7:
        colors.append('blue')
    elif float(city['temperature']) < 11:
        colors.append('red')
    else: colors.append('yellow')
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.scatter(x, y, c=colors)
plt.show()

# %%
# Introduction to bar charts
bars = ['Bar1', 'Bar2', 'Bar3']
heights = [2, 6, 4]
plt.xticks([0,1,2], bars)
plt.bar([0,1,2], heights)
plt.show()

# %%
# Bar chart showing populations of countries with 'ia' in their name
bars = [] # countries with 'ia' in their name
heights = [] # population of those countries
for country in countries:
    if 'ia' in country['country']:
        bars.append(country['country'])
        heights.append(float(country['population']))
numbars = len(bars)
# range(numbars) in following command yields [0,1,...,numbars-1]
plt.xticks(range(numbars), bars, rotation='vertical')
plt.bar(range(numbars), heights)
plt.xlabel('country')
plt.ylabel('population')
plt.show()

# %%
# Introduction to pie charts
sizes = [10, 20, 30]
lbls = ['small', 'medium', 'large']
plt.pie(sizes, labels=lbls, autopct='%1.1f%%')
plt.show()

# %%
# Pie chart showing number of EU countries versus non-EU countries
numEU = 0
numNotEU = 0
for country in countries:
    if country['EU'] == 'yes':
        numEU += 1
    else:
        numNotEU +=1
sizes = [numEU, numNotEU]
lbls = ['EU', 'not EU']
plt.pie(sizes, labels=lbls, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ### <font color="green">Your Turn: World Cup Data</font>

# %%
# Read Players.csv and Teams.csv into lists of dictionaries
players = []
with open('Players.csv','rU') as f:
    rows = csv.DictReader(f)
    for r in rows:
        players.append(r)
teams = []
with open('Teams.csv','rU') as f:
    rows = csv.DictReader(f)
    for r in rows:
        teams.append(r)
players
teams
# Out:
# /home/aidar/Tools/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: 'U' mode is deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/aidar/Tools/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: 'U' mode is deprecated
# [OrderedDict([('team', 'Brazil'),
#               ('ranking', '1'),
#               ('games', '5'),
#               ('wins', '3'),
#               ('draws', '1'),
#               ('losses', '1'),
#               ('goalsFor', '9'),
#               ('goalsAgainst', '4'),
#               ('yellowCards', '7'),
#               ('redCards', '2')]),
#  OrderedDict([('team', 'Spain'),
#               ('ranking', '2'),
#               ('games', '6'),
#               ('wins', '5'),
#               ('draws', '0'),
#               ('losses', '1'),
#               ('goalsFor', '7'),
#               ('goalsAgainst', '2'),
#               ('yellowCards', '3'),
#               ('redCards', '0')]),
#  OrderedDict([('team', 'Portugal'),
#               ('ranking', '3'),
#               ('games', '4'),
#               ('wins', '1'),
#               ('draws', '2'),
#               ('losses', '1'),
#               ('goalsFor', '7'),
#               ('goalsAgainst', '1'),
#               ('yellowCards', '8'),
#               ('redCards', '1')]),
#  OrderedDict([('team', 'Netherlands'),
#               ('ranking', '4'),
#               ('games', '6'),
#               ('wins', '6'),
#               ('draws', '0'),
#               ('losses', '0'),
#               ('goalsFor', '12'),
#               ('goalsAgainst', '5'),
#               ('yellowCards', '15'),
#               ('redCards', '0')]),
#  OrderedDict([('team', 'Italy'),
#               ('ranking', '5'),
#               ('games', '3'),
#               ('wins', '0'),
#               ('draws', '2'),
#               ('losses', '1'),
#               ('goalsFor', '4'),
#               ('goalsAgainst', '5'),
#               ('yellowCards', '5'),
#               ('redCards', '0')]),
#  OrderedDict([('team', 'Germany'),
#               ('ranking', '6'),
#               ('games', '6'),
#               ('wins', '4'),
#               ('draws', '0'),
#               ('losses', '2'),
#               ('goalsFor', '13'),
#               ('goalsAgainst', '3'),
#               ('yellowCards', '8'),
#               ('redCards', '1')]),
#  OrderedDict([('team', 'Argentina'),
#               ('ranking', '7'),
#               ('games', '5'),
#               ('wins', '4'),
#               ('draws', '0'),
#               ('losses', '1'),
#               ('goalsFor', '10'),
#               ('goalsAgainst', '6'),
#               ('yellowCards', '7'),
#               ('redCards', '0')]),
#  OrderedDict([('team', 'England'),
#               ('ranking', '8'),
#               ('games', '4'),
#               ('wins', '1'),
#               ('draws', '2'),
#               ('losses', '1'),
#               ('goalsFor', '3'),
#               ('goalsAgainst', '5'),
#               ('yellowCards', '6'),
#               ('redCards', '0')]),
#  OrderedDict([('team', 'France'),
#               ('ranking', '9'),
#               ('games', '3'),
#               ('wins', '0'),
#               ('draws', '1'),
#               ('losses', '2'),
#               ('goalsFor', '1'),
#               ('goalsAgainst', '4'),
#               ('yellowCards', '6'),
#               ('redCards', '1')]),
#  OrderedDict([('team', 'Greece'),
#               ('ranking', '13'),
#               ('games', '3'),
#               ('wins', '1'),
#               ('draws', '0'),
#               ('losses', '2'),
#               ('goalsFor', '2'),
#               ('goalsAgainst', '5'),
#               ('yellowCards', '5'),
#               ('redCards', '0')]),
#  OrderedDict([('team', 'USA'),
#               ('ranking', '14'),
#               ('games', '4'),
#               ('wins', '1'),
#               ('draws', '2'),
#               ('losses', '1'),
#               ('goalsFor', '5'),
#               ('goalsAgainst', '5'),
#               ('yellowCards', '9'),
#               ('redCards', '0')]),
#  OrderedDict([('team', 'Serbia'),
#               ('ranking', '15'),
#               ('games', '3'),
#               ('wins', '1'),
#               ('draws', '0'),
#               ('losses', '2'),
#               ('goalsFor', '2'),
#               ('goalsAgainst', '3'),
#               ('yellowCards', '8'),
#               ('redCards', '1')]),
#  OrderedDict([('team', 'Uruguay'),
#               ('ranking', '16'),
#               ('games', '6'),
#               ('wins', '3'),
#               ('draws', '2'),
#               ('losses', '1'),
#               ('goalsFor', '9'),
#               ('goalsAgainst', '5'),
#               ('yellowCards', '8'),
#               ('redCards', '2')]),
#  OrderedDict([('team', 'Mexico'),
#               ('ranking', '17'),
#               ('games', '4'),
#               ('wins', '1'),
#               ('draws', '1'),
#               ('losses', '2'),
#               ('goalsFor', '4'),
#               ('goalsAgainst', '5'),
#               ('yellowCards', '9'),
#               ('redCards', '0')]),
#  OrderedDict([('team', 'Chile'),
#               ('ranking', '18'),
#               ('games', '4'),
#               ('wins', '2'),
#               ('draws', '0'),
#               ('losses', '2'),
#               ('goalsFor', '3'),
#               ('goalsAgainst', '5'),
#               ('yellowCards', '13'),
#               ('redCards', '1')]),
#  OrderedDict([('team', 'Cameroon'),
#               ('ranking', '19'),
#               ('games', '3'),
#               ('wins', '0'),
#               ('draws', '0'),
#               ('losses', '3'),
#               ('goalsFor', '2'),
#               ('goalsAgainst', '5'),
#               ('yellowCards', '5'),
#               ('redCards', '0')]),
#  OrderedDict([('team', 'Australia'),
#               ('ranking', '20'),
#               ('games', '3'),
#               ('wins', '1'),
#               ('draws', '1'),
#               ('losses', '1'),
#               ('goalsFor', '3'),
#               ('goalsAgainst', '6'),
#               ('yellowCards', '7'),
#               ('redCards', '2')]),
#  OrderedDict([('team', 'Nigeria'),
#               ('ranking', '21'),
#               ('games', '3'),
#               ('wins', '0'),
#               ('draws', '1'),
#               ('losses', '2'),
#               ('goalsFor', '3'),
#               ('goalsAgainst', '5'),
#               ('yellowCards', '5'),
#               ('redCards', '1')]),
#  OrderedDict([('team', 'Switzerland'),
#               ('ranking', '24'),
#               ('games', '3'),
#               ('wins', '1'),
#               ('draws', '1'),
#               ('losses', '1'),
#               ('goalsFor', '1'),
#               ('goalsAgainst', '1'),
#               ('yellowCards', '8'),
#               ('redCards', '1')]),
#  OrderedDict([('team', 'Slovenia'),
#               ('ranking', '25'),
#               ('games', '3'),
#               ('wins', '1'),
#               ('draws', '1'),
#               ('losses', '1'),
#               ('goalsFor', '3'),
#               ('goalsAgainst', '3'),
#               ('yellowCards', '9'),
#               ('redCards', '0')]),
#  OrderedDict([('team', 'Ivory Coast'),
#               ('ranking', '27'),
#               ('games', '3'),
#               ('wins', '1'),
#               ('draws', '1'),
#               ('losses', '1'),
#               ('goalsFor', '4'),
#               ('goalsAgainst', '3'),
#               ('yellowCards', '5'),
#               ('redCards', '0')]),
#  OrderedDict([('team', 'Algeria'),
#               ('ranking', '30'),
#               ('games', '3'),
#               ('wins', '0'),
#               ('draws', '1'),
#               ('losses', '2'),
#               ('goalsFor', '0'),
#               ('goalsAgainst', '2'),
#               ('yellowCards', '4'),
#               ('redCards', '2')]),
#  OrderedDict([('team', 'Paraguay'),
#               ('ranking', '31'),
#               ('games', '5'),
#               ('wins', '1'),
#               ('draws', '3'),
#               ('losses', '1'),
#               ('goalsFor', '3'),
#               ('goalsAgainst', '2'),
#               ('yellowCards', '9'),
#               ('redCards', '0')]),
#  OrderedDict([('team', 'Ghana'),
#               ('ranking', '32'),
#               ('games', '5'),
#               ('wins', '2'),
#               ('draws', '2'),
#               ('losses', '1'),
#               ('goalsFor', '5'),
#               ('goalsAgainst', '4'),
#               ('yellowCards', '11'),
#               ('redCards', '0')]),
#  OrderedDict([('team', 'Slovakia'),
#               ('ranking', '34'),
#               ('games', '4'),
#               ('wins', '1'),
#               ('draws', '1'),
#               ('losses', '2'),
#               ('goalsFor', '5'),
#               ('goalsAgainst', '7'),
#               ('yellowCards', '11'),
#               ('redCards', '0')]),
#  OrderedDict([('team', 'Denmark'),
#               ('ranking', '36'),
#               ('games', '3'),
#               ('wins', '1'),
#               ('draws', '0'),
#               ('losses', '2'),
#               ('goalsFor', '3'),
#               ('goalsAgainst', '6'),
#               ('yellowCards', '6'),
#               ('redCards', '0')]),
#  OrderedDict([('team', 'Honduras'),
#               ('ranking', '38'),
#               ('games', '3'),
#               ('wins', '0'),
#               ('draws', '1'),
#               ('losses', '2'),
#               ('goalsFor', '0'),
#               ('goalsAgainst', '3'),
#               ('yellowCards', '7'),
#               ('redCards', '0')]),
#  OrderedDict([('team', 'Japan'),
#               ('ranking', '45'),
#               ('games', '4'),
#               ('wins', '2'),
#               ('draws', '1'),
#               ('losses', '1'),
#               ('goalsFor', '4'),
#               ('goalsAgainst', '2'),
#               ('yellowCards', '7'),
#               ('redCards', '0')]),
#  OrderedDict([('team', 'South Korea'),
#               ('ranking', '47'),
#               ('games', '4'),
#               ('wins', '1'),
#               ('draws', '1'),
#               ('losses', '2'),
#               ('goalsFor', '6'),
#               ('goalsAgainst', '8'),
#               ('yellowCards', '6'),
#               ('redCards', '0')]),
#  OrderedDict([('team', 'New Zealand'),
#               ('ranking', '78'),
#               ('games', '3'),
#               ('wins', '0'),
#               ('draws', '3'),
#               ('losses', '0'),
#               ('goalsFor', '2'),
#               ('goalsAgainst', '2'),
#               ('yellowCards', '6'),
#               ('redCards', '0')]),
#  OrderedDict([('team', 'South Africa'),
#               ('ranking', '83'),
#               ('games', '3'),
#               ('wins', '1'),
#               ('draws', '1'),
#               ('losses', '1'),
#               ('goalsFor', '3'),
#               ('goalsAgainst', '5'),
#               ('yellowCards', '4'),
#               ('redCards', '1')]),
#  OrderedDict([('team', 'North Korea'),
#               ('ranking', '105'),
#               ('games', '3'),
#               ('wins', '0'),
#               ('draws', '0'),
#               ('losses', '3'),
#               ('goalsFor', '1'),
#               ('goalsAgainst', '12'),
#               ('yellowCards', '2'),
#               ('redCards', '0')])]

# %%
# Create a scatterplot of players showing passes made (y-axis)
# versus minutes played (x-axis). Color each player based on their
# position (goalkeeper, defender, midfielder, forward).

x = []
y = []
colors = []

for player in players:
    x.append(float(player['passes']))
    y.append(float(player['minutes']))
    if player['position']=='goalkeeper':
        colors.append('red')
    elif player['position']=='defender':
        colors.append('blue')
    elif player['position']=='midfielder':
        colors.append('green')
    elif player['position']=='forward':
        colors.append('yellow')

plt.xlabel('Minutes')
plt.ylabel('Passes')
plt.scatter(x, y, c=colors)
plt.show()

# %%
# Create a bar chart showing the number of teams with 0, 1, and 2 red cards.
# Reminder: redCards is a string, so convert or compare accordingly
bars = ['zero', 'one', 'two'] # number of red cards
heights = [0, 0, 0] # number of teams with zero/one/two red cards
# your code here

for team in teams:
    heights[int(team["redCards"])]+=1
plt.xticks([0,1,2], bars)
plt.bar([0,1,2], heights)
plt.show()

# %%
# Create a pie chart showing the relative percentage of teams
# with 0, 1, and 2 red cards.
# Reminder: redCards is a string, so convert or compare accordingly
lbls = ['0', '1', '2']
plt.pie(heights, labels=lbls, autopct='%1.1f%%')
plt.show()

# %%
# BONUS!
# Write a loop that interactively asks the user to enter a team name.
# If the team exists, create a pie chart showing how many players the team
# has in each of the four positions.
# If the team doesn't exist, print "Team not in 2010 World Cup".
# If 'quit' is entered, terminate the loop.
# Note: To read a string from the user instead of a number, use
# raw_input() instead of input()
teamName=input("Enter a team name: ")
while teamName!='quit':
    lbls = ['goalkeeper', 'defender', 'midfielder', 'forward']
    sizes = [0,0,0,0]
    isFound=False
    for player in players:
        if player['team']==teamName:
            isFound=True
            if player['position']=='goalkeeper':
                sizes[0]+=1
            elif player['position']=='defender':
                sizes[1]+=1
            elif player['position']=='midfielder':
                sizes[2]+=1
            elif player['position']=='forward':
                sizes[3]+=1
    if isFound==False:
        print('Team not in 2010 World Cup')
    else:
        plt.pie(sizes, labels=lbls, autopct='%1.1f%%')
        plt.show()
    teamName=input("Enter a team name: ")
# Out:
# Enter a team name: ALgeria
# Team not in 2010 World Cup
# Enter a team name: Algeria
# Enter a team name: Honduras
# Enter a team name: Argentina
# Enter a team name: quit
